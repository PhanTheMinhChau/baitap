# %% [markdown]
# THỰC HÀNH TRỰC QUAN HÓA DỮ LIỆU NÂNG CAO

# %% [markdown]
# Trong thực tế, các chiều dữ liệu có thể được trực quan hóa từng đối một với nhau. Trong Python, những hình vẽ dạng này được gọi là paired plots.
#
# Hãy sử dụng tài liệu tham khảo dưới đây để áp dụng vẽ paired plots cho tập dữ liệu microbiome.csv và baseball.csv
#
# Lưu ý có giải thích code trong phần markdown tương ứng
#
# Link: https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
baseball = pd.read_csv("baseball.csv")
baseball = baseball[['id','player','year','stint','team']]
baseball.head()
# Out:
#       id     player  year  stint team
# 0  88641  womacto01  2006      2  CHN
# 1  88643  schilcu01  2006      1  BOS
# 2  88645  myersmi01  2006      1  NYA
# 3  88649  helliri01  2006      1  MIL
# 4  88650  johnsra05  2006      1  NYA

# %%
sns.pairplot(baseball,hue='team')
sns.despine()
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)

# %%
micro = pd.read_csv('microbiome.csv')
micro.head()
# Out:
#         Taxon  Patient  Tissue  Stool
# 0  Firmicutes        1     632    305
# 1  Firmicutes        2     136   4182
# 2  Firmicutes        3    1174    703
# 3  Firmicutes        4     408   3946
# 4  Firmicutes        5     831   8605

# %%
sns.pairplot(micro,hue="Taxon")
sns.despine()
